# %%
from IPython.display import Image

# %% [markdown]
# # YouTube Posting by Label
#
# I will be looking at our various label groups and showing how active their channels have been by month over the past 6 monhts. I will also include an executive summary that stacks the label averages against each other so we can see the average activity across all channels by label. This will allow us to monitor the activity of our labels helping us focus our attention on the labels who need the most help while also allowing us to reward the labels that are performing well.
#
# The first graph I will show is the exectuive summary:

# %%
Image(filename='plots/group-plot.png')

# %% [markdown]
# ## label specific graphs
#
# I was also able to generate a plot for each label showing the activity of the channels within that label. Below you will see graphs for the top two labels, label 12 and label 63:

# %%
Image(filename='plots/12.png')

# %%
Image(filename='plots/63.png')
